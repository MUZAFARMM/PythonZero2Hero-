# %% [markdown]
# ## Input Output

# %% [markdown]
# The purpose of computer is to process the data and return results.
#
#
# *   Data given to the computer is callled input
# *   Results returned by the computer is called as Output.
# ![image.png](data:image/png;base64,...)
#
# * Python provides both input aand output statements.

# %% [markdown]
# ## Output statements
# To display output or results.Python provides print() function.
#
# 1. The print("String") statement.
# 2. The print(Variable list) statement.
# 3. The print(object) statement.
# 4. The print("String", Variable List) statement.
# 5. The print(Formatted String) statement.

# %% [markdown]
# ### The print("String") statement.

# %%
print("BitByBit") # within double Quotes 
print('BitByBit') # within single Quotes
# Out:
# BitByBit
# BitByBit

# %%
print("This is crash course from /n BitBitBit") # Errorneously using forword slash
print("This is crash course from \nBitBitBit")  # Using Escape character \n , which indicates new line
# Just like /n if we want \n as a part of string then use \ before the escpae sequence
print("This is crash course from \\n BitBitBit") # Escape the effect of escape sequence
# Out:
# This is crash course from /n BitBitBit
# This is crash course from
# BitBitBit
# This is crash course from \n BitBitBit

# %%
# Repeating operator '*'
print(3*"This is crash course from BitBitBit ")
# Out:
# This is crash course from BitBitBit This is crash course from BitBitBit This is crash course from BitBitBit

# %%
# concatenation operator '+'
print("This is crash course from BitBitBit" +""+ "\nLeanning is fun") #
print("This is crash course= ", "from BitBitBit") # When the print sees comma , it will assume that the values are different and hence a space should be used between for clarity.
# Out:
# This is crash course from BitBitBit
# Leanning is fun
# This is crash course=  from BitBitBit

# %%
x=19
print("x= %i" % x)
# Out:
# x= 19

# %%
x=19
print("x= %d" % x)
# Out:
# x= 19

# %%
x="mmm"
y=10
print("x= %-20s" % x)
print("x= %20s" % x)
# Out:
# x= mmm
# x=                  mmm

# %% [markdown]
# ## Input statements
#
# * Input Statements
# * Acessing Multiple inputsm in same line
# * command line Arguments
